# %% [markdown]
# # Regularisation
#
# In this lab we will explore different methods for regularising networks to reduce overfitting and improve generalisation. This uses the material covered in the [fourth lecture slides](http://www.inf.ed.ac.uk/teaching/courses/mlp/2018-19/mlp04-reg.pdf).

# %% [markdown]
# # Exercise 1: L1 and L2 penalties
#
# In the previous lab notebook we explored the issue of overfitting. There we saw that this arises when the model is 'too complex' ($\sim$ has too many degrees of freedom / parameters) for the amount of data we have available.
#
# One method for trying to reduce overfitting is therefore to try to decrease the flexibility of the model. We can do this by simply reducing the number of free parameters in the model (e.g. by using a shallower model with fewer layers or layers with smaller dimensionality). More generally however we might want some way of more continuously varying the effective flexibility of a model with a fixed architecture.
#
# A common method for doing this is to add an additional term to the objective function being minimised during training which penalises some measure of the complexity of a model as a function of the model parameters. The aim of training is then to minimise with respect to the model parameters the sum $E^\star$ of the data-driven error function term $\bar{E}$ and a model complexity term $C$.
#
# \begin{equation}
#    E^\star =
#    \underbrace{\bar{E}}_{\textrm{data term}} + \underbrace{C}_{\textrm{complexity term}}
# \end{equation}
#
# We need the complexity term $C$ to be easy to compute and differentiable with respect to the model parameters. A common choice is to use terms involving the *norms* ($\sim$ a measure of size) of the parameters. This penalises models with large parameter values. Two commonly used norms are the L1 and L2 norms.
#
# For a $D$ dimensional vector $\mathbf{v}$ the L1 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_1 = \sum_{d=1}^D \left| v_d \right|,
# \end{equation}
#
# and the L2 norm is defined as
#
# \begin{equation}
# \| \boldsymbol{v} \|_2 = \left[ \sum_{d=1}^D \left( v_d^2 \right) \right]^{\frac{1}{2}}.
# \end{equation}
#
# For a $K \times D$ matrix $\mathbf{M}$, we will define norms by collapsing the matrix to a vector $\boldsymbol{m} = \mathrm{vec}\left[\mathbf{M}\right] = \left[ M_{1,1} \dots M_{1,D} ~ M_{2,1} \dots M_{K,D} \right]^{\rm T}$ and then taking the norm as defined above of this resulting vector (practically this just results in summing over two sets of indices rather than one).
#
# The overall complexity penalty term $C$ is defined as a sum over individual complexity terms for each of the $P$ parameters of the model
#
# \begin{equation}
#     C = \sum_{i=1}^P \left[ C^{(i)} \right]
# \end{equation}
#
# Some of these per-parameter penalty terms $C^{(i)}$ may be set to zero if we do not wish to penalise the size of the corresponding parameter.
#
# To enable us to tradeoff between the model complexity and data error terms, it is typical to introduce positive scalar coefficients $\beta_i$ to scale the penalty term on the $i$th parameter. A *L1 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is then commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L1}} =
#   \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_1 =
#   \beta_i  \sum_{d=1}^D \left| p^{(i)}_d \right|.
# \end{equation}
#
# This has a gradient with respect to the parameter vector
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L1}}}{\partial p^{(i)}_d} = \beta_i \, \textrm{sgn}\left( p^{(i)}_d \right)
# \end{equation}
#
# where $\textrm{sgn}(u) = +1$ if $u > 0$, $\textrm{sgn}(u) = -1$ if $u < 0$ (and is not well defined for $u=0$ though a common convention is to have $\textrm{sgn}(0) = 0$).
#
# Similarly a *L2 penalty* on the $i$th vector parameter $\boldsymbol{p}^{(i)}$ (or matrix parameter collapsed to a vector) is commonly defined as
#
# \begin{equation}
#   C^{(i)}_{\textrm{L2}} =
#   \frac{1}{2} \beta_i \left\| \boldsymbol{p}^{(i)} \right\|_2^2 =
#   \frac{1}{2} \beta_i \sum_{d=1}^D \left[ \left( p^{(i)}_d \right)^2 \right].
# \end{equation}
#
# Somewhat confusingly this is proportional to the square of the L2 norm rather than the L2 norm itself, however it is an almost universal convention to call this an L2 penalty so we will stick with this nomenclature here. The $\frac{1}{2}$ term is less universal and is sometimes not included; we include it here for consistency with how we defined the sum of squared errors cost. Similarly to that case, the $\frac{1}{2}$ cancels when calculating the gradient with respect to the parameter
#
# \begin{equation}
#   \frac{\partial C^{(i)}_{\textrm{L2}}}{\partial p^{(i)}_d} = \beta_i p^{(i)}_d
# \end{equation}
#
# Use the above definitions for the L1 and L2 penalties for a parameter and corresponding gradients to implement the `__call__` and `grad` methods respectively for the skeleton `L1Penalty` and `L2Penalty` class definitions below. The `coefficient` property of these classes should be used as the $\beta_i$ value in the equations above. The parameter the penalty term (or gradient) is being evaluated for will be either a one or two-dimensional NumPy array (corresponding to a vector or matrix parameter respectively) and your implementations should be able to cope with both cases.

# %%
import numpy as np
seed = 22102017 
rng = np.random.RandomState(seed)
class L1Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L1 norm.
    """
    
    def __init__(self, coefficient):
        """Create a new L1 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L1 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        return np.sum(np.abs(parameter)) * self.coefficient
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        cond = [parameter > 0, parameter < 0, parameter == 0]
        values = [1, -1, 0]
        return np.select(cond,values) * self.coefficient
    
    def __repr__(self):
        return 'L1Penalty({0})'.format(self.coefficient)
        

class L2Penalty(object):
    """L1 parameter penalty.
    
    Term to add to the objective function penalising parameters
    based on their L2 norm.
    """

    def __init__(self, coefficient):
        """Create a new L2 penalty object.
        
        Args:
            coefficient: Positive constant to scale penalty term by.
        """
        assert coefficient > 0., 'Penalty coefficient must be positive.'
        self.coefficient = coefficient
        
    def __call__(self, parameter):
        """Calculate L2 penalty value for a parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty term.
        """
        return self.coefficient/2 * np.sum(np.square(parameter))
        
    def grad(self, parameter):
        """Calculate the penalty gradient with respect to the parameter.
        
        Args:
            parameter: Array corresponding to a model parameter.
            
        Returns:
            Value of penalty gradient with respect to parameter. This
            should be an array of the same shape as the parameter.
        """
        return self.coefficient*parameter
    
    def __repr__(self):
        return 'L2Penalty({0})'.format(self.coefficient)

# %% [markdown]
# Test your implementations by running the cells below.

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l1_cost_1 = 10.5
true_l1_grad_1 = np.array([[0.5, 0.5, -0.5, 0.5], [0.5, -0.5, 0.5, -0.5]])
true_l1_cost_2 = 3.
true_l1_grad_2 = np.array([0.5, -0.5, -0.5, 0.5, 0.5])
l1 = L1Penalty(0.5)
if (not np.allclose(l1(test_params_1), true_l1_cost_1) or
        not np.allclose(l1(test_params_2), true_l1_cost_2)):
    print('L1Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l1.grad(test_params_1), true_l1_grad_1) or 
          not np.allclose(l1.grad(test_params_2), true_l1_grad_2)):
    print('L1Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L1Penalty')
# Out:
# All test values calculated correctly for L1Penalty

# %%
test_params_1 = np.array([[0.5, 0.3, -1.2, 5.8], [0.2, -3.1, 4.9, -5.0]])
test_params_2 = np.array([0.8, -0.6, -0.3, 1.5, 2.8])
true_l2_cost_1 = 23.52
true_l2_grad_1 = np.array([[0.25, 0.15, -0.6, 2.9], [0.1, -1.55, 2.45, -2.5]])
true_l2_cost_2 = 2.795
true_l2_grad_2 = np.array([0.4, -0.3, -0.15, 0.75, 1.4])
l2 = L2Penalty(0.5)
if (not np.allclose(l2(test_params_1), true_l2_cost_1) or
        not np.allclose(l2(test_params_2), true_l2_cost_2)):
    print('L2Penalty.__call__ giving incorrect value(s).')
elif (not np.allclose(l2.grad(test_params_1), true_l2_grad_1) or 
          not np.allclose(l2.grad(test_params_2), true_l2_grad_2)):
    print('L2Penalty.grad giving incorrect value(s).')
else:
    print('All test values calculated correctly for L2Penalty')
# Out:
# All test values calculated correctly for L2Penalty

# %% [markdown]
# ## Exercise 2: Training with regularisation

# %% [markdown]
# Previously in the second laboratory you implemented a function `grads_wrt_params`  to calculate the gradient of an error function with respect to the parameters of an affine model (layer), given gradients of the error function with respect to the model (layer) outputs.
#
# If we are training a model using a regularised objective function, we need to additionally calculate the gradients of the regularisation penalty terms with respect to the parameters and add these to the error function gradient terms. Following from the definition of the regularised objective $E^\star$ above we have that the gradient of the overall objective with respect to the $d$th element of the $i$th model parameter is
#
# \begin{equation}
#     \frac{\partial E^\star}{\partial p^{(i)}_d} =
#     \frac{\partial \bar{E}}{\partial p^{(i)}_d} +
#     \frac{\partial C}{\partial p^{(i)}_d}
# \end{equation}
#
# We have already discussed in the second lab notebook how to calculate the error function gradient term $\frac{\partial \bar{E}}{\partial p^{(i)}_d}$. As the model complexity term is composed of a sum of per parameter terms and only one of these will depend on the $i$th parameter we can write
#
# \begin{equation}
#     \frac{\partial C}{\partial p^{(i)}_d} = \frac{\partial C^{(i)}}{\partial p^{(i)}_d}
# \end{equation}
#
# which corresponds to the penalty term gradients you implemented above. To enable us to use the same `Optimiser` implementation that we have previously used to train models without regularisation, we have altered the implementation of the `AffineLayer` class to allow us to specify penalty terms on the weight matrix and bias vector when creating an instance of the class and to add the corresponding penalty gradients to the returned value from the `grads_wrt_params` method.
#
# The penalty terms need to be specified as a class matching the interface of the `L1Penalty` and `L2Penalty` classes you implemented above, defining both a `__call__` method to calculate the penalty value for a parameter and a `grad` method to calculate the gradient of the penalty with respect to the parameter. Separate penalties can be specified for the weight and bias parameters, with it common to only regularise the weight parameters.
#
# The penalty terms for a layer are specifed using the `weights_penalty` and `biases_penalty` arguments to the `__init__` method of the `AffineLayer` class. If either (or both) of these are set to `None` (the default) no regularisation is applied to the corresponding parameter.
#
# Using the `L1Penalty` and `L2Penalty` classes you implemented in the previous exercise, train models to classify MNIST digit images with
#
#   * no regularisation
#   * an L1 penalty with coefficient $10^{-5}$ on the all of the weight matrix parameters
#   * an L1 penalty with coefficient $10^{-3}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-4}$ on the all of the weight matrix parameters
#   * an L2 penalty with coefficient $10^{-2}$ on the all of the weight matrix parameters
#
# The models should all have three affine layers each interspersed with a `ReluLayer` (as implemented in the Lab 3 on Multiple Layer Models) and intermediate layers between the input and output should have dimensionalities of 100. The final output layer should be an `AffineLayer` (the model outputting the logarithms of the non-normalised class probabilties) and you should use the `CrossEntropySoftmaxError` as the error function (which calculates the softmax of the model outputs to convert to normalised class probabilities before calculating the corresponding multi-class cross entropy error).
#
# Use the `GlorotInit` class (which implements the weight initialisation technique discussed in the [fifth lecture](http://www.inf.ed.ac.uk/teaching/courses/mlp/2018-19/mlp05-learn.pdf)) to initialise the weights in all layers, using a gain of 0.5 (this adjusts for the fact that the rectified linear sets zeros all negative inputs), and initialises the biases to zero with a `ConstantInit` object.
#
# As an example the necessary parameter initialisers, model and error can be defined using
#
# ```python
# weights_init = GlorotUniformInit(0.5, rng)
# biases_init = ConstantInit(0.)
# input_dim, output_dim, hidden_dim = 784, 10, 100
# model = MultipleLayerModel([
#     AffineLayer(input_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, hidden_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty),
#     ReluLayer(),
#     AffineLayer(hidden_dim, output_dim, weights_init,
#                 biases_init, weights_penalty=weights_penalty)
# ])
# error = CrossEntropySoftmaxError()
# ```
#
# This assumes all the relevant classes have been imported from their modules, a penalty object has been assigned to `weights_penalty` and a seeded random number generator assigned to `rng`.
#
# For each regularisation scheme, train the model for 100 epochs with a batch size of 50 and using a gradient descent with momentum learning rule with learning rate 0.01 and momentum coefficient 0.9. For each regularisation scheme you should store the run statistics (output of `Optimiser.train`) and the final values of the first layer weights for each of the trained models.

# %%
from mlp.initialisers import GlorotUniformInit,ConstantInit
from mlp.models import MultipleLayerModel
from mlp.layers import AffineLayer,ReluLayer
from mlp.data_providers import DataProvider
import numpy as np
import logging
from mlp.data_providers import MNISTDataProvider
from mlp.errors import CrossEntropySoftmaxError
from mlp.learning_rules import MomentumLearningRule
from matplotlib import pyplot as plt
from mlp.optimisers import Optimiser
# The below code will set up the data providers, random number
# generator and logger objects needed for training runs. As
# loading the data from file take a little while you generally
# will probably not want to reload the data providers on
# every training run. If you wish to reset their state you
# should instead use the .reset() method of the data providers.


# Seed a random number generator
seed = 11102019
rng = np.random.RandomState(seed)
batch_size = 50
# Set up a logger object to print info about the training run to stdout
logger = logging.getLogger()
logger.setLevel(logging.INFO)
logger.handlers = [logging.StreamHandler()]

# Create data provider objects for the MNIST data set
train_data = MNISTDataProvider('train', batch_size=batch_size, rng=rng)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = MNISTDataProvider('test', batch_size=batch_size, rng=rng)

train_data.reset()
valid_data.reset()
test_data.reset()
lr = 0.9
num_epochs=100
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
input_dim, output_dim, hidden_dim = 784, 10, 100
models = []
L1_models = []
L2_models = []
L2 = [1e-5,1e-3]
L1 = [1e-4,1e-2]
L1_weights=[]
L2_weights=[]
for i in range(2):
    l1_penalty = L1Penalty(L1[i])
    model_l1 = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init,
                    biases_init, weights_penalty=l1_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init,
                    biases_init, weights_penalty=l1_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init,
                    biases_init, weights_penalty=l1_penalty)
    ])


    l2_penalty = L2Penalty(L2[i])
    model_l2 = MultipleLayerModel([
        AffineLayer(input_dim, hidden_dim, weights_init,
                    biases_init, weights_penalty=l2_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, hidden_dim, weights_init,
                    biases_init, weights_penalty=l2_penalty),
        ReluLayer(),
        AffineLayer(hidden_dim, output_dim, weights_init,
                    biases_init, weights_penalty=l2_penalty)
    ])


    L1_models.append(model_l1)
    L2_models.append(model_l2)
learning_rule = MomentumLearningRule(learning_rate=lr)
error = CrossEntropySoftmaxError()
data_monitors = {'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}


# Use the created objects to initialise a new Optimiser instance.
error_val_l1 = []
error_train_l1 = []

stats  = []
for model in L1_models:
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors)

    stat, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=1)
    error_val_l1.append(stat[1:, keys['error(valid)']])
    error_train_l1.append(stat[1:, keys['error(train)']])
    stats.append(stat)
    L1_weights.append(model.params[0][0])

error_val_l2 = []
error_train_l2 = []

for model in L2_models:
    optimiser = Optimiser(
        model, error, learning_rule, train_data, valid_data, data_monitors)

    stat, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=1)
    error_val_l2.append(stat[1:, keys['error(valid)']])
    error_train_l2.append(stat[1:, keys['error(train)']])

    stats.append(stat)
    L2_weights.append(model.params[0][0])
# Out:
# Epoch 1: 3.4s to complete
#     error(train)=2.38e+00, acc(train)=9.86e-02, error(valid)=2.38e+00, acc(valid)=9.91e-02
# Epoch 2: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01
# Epoch 3: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 4: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 5: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 6: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 7: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 8: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 9: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 10: 3.5s to complete
#     error(train)=2.32e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 11: 3.6s to complete
#     error(train)=2.36e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 12: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 13: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.04e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 14: 3.2s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 15: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 16: 3.5s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 17: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 18: 3.5s to complete
#     error(train)=2.33e+00, acc(train)=9.68e-02, error(valid)=2.33e+00, acc(valid)=1.01e-01
# Epoch 19: 3.6s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 20: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 21: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 22: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 23: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.68e-02, error(valid)=2.33e+00, acc(valid)=1.01e-01
# Epoch 24: 3.5s to complete
#     error(train)=2.37e+00, acc(train)=9.72e-02, error(valid)=2.37e+00, acc(valid)=9.83e-02
# Epoch 25: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 26: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 27: 3.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 28: 3.7s to complete
#     error(train)=2.32e+00, acc(train)=9.72e-02, error(valid)=2.32e+00, acc(valid)=9.83e-02
# Epoch 29: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 30: 3.5s to complete
#     error(train)=2.31e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01
# Epoch 31: 3.6s to complete
#     error(train)=2.32e+00, acc(train)=9.86e-02, error(valid)=2.32e+00, acc(valid)=9.91e-02
# Epoch 32: 3.5s to complete
#     error(train)=2.36e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 33: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 34: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 35: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 36: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.72e-02, error(valid)=2.35e+00, acc(valid)=9.83e-02
# Epoch 37: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.94e-02, error(valid)=2.37e+00, acc(valid)=9.90e-02
# Epoch 38: 3.4s to complete
#     error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01
# Epoch 39: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 40: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 41: 3.4s to complete
#     error(train)=2.38e+00, acc(train)=1.02e-01, error(valid)=2.37e+00, acc(valid)=1.03e-01
# Epoch 42: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.68e-02, error(valid)=2.34e+00, acc(valid)=1.01e-01
# Epoch 43: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 44: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 45: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 46: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 47: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 48: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 49: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.04e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 50: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 51: 3.5s to complete
#     error(train)=2.32e+00, acc(train)=9.98e-02, error(valid)=2.32e+00, acc(valid)=9.61e-02
# Epoch 52: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 53: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.03e-01, error(valid)=2.36e+00, acc(valid)=1.09e-01
# Epoch 54: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=1.14e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01
# Epoch 55: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.02e-01, error(valid)=2.35e+00, acc(valid)=1.03e-01
# Epoch 56: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 57: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 58: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 59: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 60: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 61: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=9.72e-02, error(valid)=2.35e+00, acc(valid)=9.83e-02
# Epoch 62: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 63: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=1.14e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01
# Epoch 64: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 65: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 66: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 67: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 68: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.35e+00, acc(valid)=9.61e-02
# Epoch 69: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 70: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.03e-01
# Epoch 71: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=9.72e-02, error(valid)=2.36e+00, acc(valid)=9.83e-02
# Epoch 72: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 73: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 74: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 75: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=9.94e-02, error(valid)=2.36e+00, acc(valid)=9.90e-02
# Epoch 76: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 77: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 78: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.72e-02, error(valid)=2.37e+00, acc(valid)=9.83e-02
# Epoch 79: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 80: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 81: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 82: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 83: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=9.94e-02, error(valid)=2.38e+00, acc(valid)=9.90e-02
# Epoch 84: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 85: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 86: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 87: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 88: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.32e+00, acc(valid)=9.67e-02
# Epoch 89: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 90: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 91: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.72e-02, error(valid)=2.35e+00, acc(valid)=9.83e-02
# Epoch 92: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.68e-02, error(valid)=2.35e+00, acc(valid)=1.01e-01
# Epoch 93: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 94: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.72e-02, error(valid)=2.35e+00, acc(valid)=9.83e-02
# Epoch 95: 3.4s to complete
#     error(train)=2.41e+00, acc(train)=9.72e-02, error(valid)=2.41e+00, acc(valid)=9.83e-02
# Epoch 96: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 97: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.72e-02, error(valid)=2.37e+00, acc(valid)=9.83e-02
# Epoch 98: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=9.94e-02, error(valid)=2.37e+00, acc(valid)=9.90e-02
# Epoch 99: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 100: 3.5s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 1: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=1.04e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 2: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 3: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 4: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 5: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 6: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 7: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.68e-02, error(valid)=2.35e+00, acc(valid)=1.01e-01
# Epoch 8: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 9: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 10: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 11: 3.3s to complete
#     error(train)=2.38e+00, acc(train)=1.03e-01, error(valid)=2.38e+00, acc(valid)=1.09e-01
# Epoch 12: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 13: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 14: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 15: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 16: 3.4s to complete
#     error(train)=2.38e+00, acc(train)=1.02e-01, error(valid)=2.38e+00, acc(valid)=1.03e-01
# Epoch 17: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 18: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 19: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 20: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 21: 3.4s to complete
#     error(train)=2.36e+00, acc(train)=1.03e-01, error(valid)=2.36e+00, acc(valid)=1.09e-01
# Epoch 22: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 23: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 24: 3.3s to complete
#     error(train)=2.38e+00, acc(train)=1.14e-01, error(valid)=2.38e+00, acc(valid)=1.06e-01
# Epoch 25: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 26: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 27: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.68e-02, error(valid)=2.34e+00, acc(valid)=1.01e-01
# Epoch 28: 3.3s to complete
#     error(train)=2.38e+00, acc(train)=9.68e-02, error(valid)=2.38e+00, acc(valid)=1.01e-01
# Epoch 29: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 30: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.37e+00, acc(valid)=9.67e-02
# Epoch 31: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 32: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 33: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 34: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 35: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.01e-02, error(valid)=2.35e+00, acc(valid)=9.15e-02
# Epoch 36: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 37: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 38: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 39: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.68e-02, error(valid)=2.35e+00, acc(valid)=1.01e-01
# Epoch 40: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 41: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.94e-02, error(valid)=2.32e+00, acc(valid)=9.90e-02
# Epoch 42: 3.3s to complete
#     error(train)=2.31e+00, acc(train)=9.98e-02, error(valid)=2.31e+00, acc(valid)=9.61e-02
# Epoch 43: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 44: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 45: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 46: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.72e-02, error(valid)=2.32e+00, acc(valid)=9.83e-02
# Epoch 47: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=9.68e-02, error(valid)=2.33e+00, acc(valid)=1.01e-01
# Epoch 48: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=1.02e-01, error(valid)=2.37e+00, acc(valid)=1.03e-01
# Epoch 49: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.86e-02, error(valid)=2.32e+00, acc(valid)=9.91e-02
# Epoch 50: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 51: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 52: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 53: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 54: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=9.68e-02, error(valid)=2.34e+00, acc(valid)=1.01e-01
# Epoch 55: 3.3s to complete
#     error(train)=2.39e+00, acc(train)=9.72e-02, error(valid)=2.39e+00, acc(valid)=9.83e-02
# Epoch 56: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.72e-02, error(valid)=2.36e+00, acc(valid)=9.83e-02
# Epoch 57: 3.4s to complete
#     error(train)=2.38e+00, acc(train)=9.86e-02, error(valid)=2.39e+00, acc(valid)=9.91e-02
# Epoch 58: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=1.02e-01, error(valid)=2.37e+00, acc(valid)=1.03e-01
# Epoch 59: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 60: 3.3s to complete
#     error(train)=2.31e+00, acc(train)=9.86e-02, error(valid)=2.31e+00, acc(valid)=9.91e-02
# Epoch 61: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 62: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 63: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 64: 3.3s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 65: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 66: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 67: 3.3s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 68: 3.3s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 69: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 70: 3.4s to complete
#     error(train)=2.37e+00, acc(train)=9.90e-02, error(valid)=2.37e+00, acc(valid)=9.67e-02
# Epoch 71: 3.3s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 72: 3.3s to complete
#     error(train)=2.38e+00, acc(train)=1.02e-01, error(valid)=2.38e+00, acc(valid)=1.03e-01
# Epoch 73: 3.5s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.32e+00, acc(valid)=9.67e-02
# Epoch 74: 3.6s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 75: 3.5s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.31e+00, acc(valid)=1.03e-01
# Epoch 76: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.36e+00, acc(valid)=9.90e-02
# Epoch 77: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 78: 3.3s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 79: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.01e-02, error(valid)=2.32e+00, acc(valid)=9.15e-02
# Epoch 80: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 81: 3.4s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 82: 3.4s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 83: 3.7s to complete
#     error(train)=2.34e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.03e-01
# Epoch 84: 3.6s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 85: 3.7s to complete
#     error(train)=2.39e+00, acc(train)=9.01e-02, error(valid)=2.39e+00, acc(valid)=9.15e-02
# Epoch 86: 3.7s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 87: 3.7s to complete
#     error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 88: 3.7s to complete
#     error(train)=2.35e+00, acc(train)=9.98e-02, error(valid)=2.35e+00, acc(valid)=9.61e-02
# Epoch 89: 3.7s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 90: 3.7s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 91: 3.7s to complete
#     error(train)=2.35e+00, acc(train)=9.98e-02, error(valid)=2.35e+00, acc(valid)=9.61e-02
# Epoch 92: 3.8s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 93: 3.7s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 94: 3.5s to complete
#     error(train)=2.32e+00, acc(train)=9.86e-02, error(valid)=2.32e+00, acc(valid)=9.91e-02
# Epoch 95: 3.5s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 96: 3.4s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 97: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=9.94e-02, error(valid)=2.32e+00, acc(valid)=9.90e-02
# Epoch 98: 3.3s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 99: 3.4s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 100: 3.5s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.34e+00, acc(valid)=9.83e-02
# Epoch 1: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 2: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.68e-02, error(valid)=2.34e+00, acc(valid)=1.01e-01
# Epoch 3: 1.5s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 4: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 5: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.72e-02, error(valid)=2.34e+00, acc(valid)=9.83e-02
# Epoch 6: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 7: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=1.04e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 8: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=1.03e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 9: 1.5s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 10: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=9.72e-02, error(valid)=2.37e+00, acc(valid)=9.83e-02
# Epoch 11: 1.6s to complete
#     error(train)=2.39e+00, acc(train)=1.14e-01, error(valid)=2.40e+00, acc(valid)=1.06e-01
# Epoch 12: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 13: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=1.14e-01, error(valid)=2.38e+00, acc(valid)=1.06e-01
# Epoch 14: 1.6s to complete
#     error(train)=2.38e+00, acc(train)=1.14e-01, error(valid)=2.39e+00, acc(valid)=1.06e-01
# Epoch 15: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 16: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 17: 1.5s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 18: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 19: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 20: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 21: 1.5s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 22: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 23: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 24: 1.5s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 25: 1.6s to complete
#     error(train)=2.39e+00, acc(train)=1.02e-01, error(valid)=2.39e+00, acc(valid)=1.03e-01
# Epoch 26: 1.5s to complete
#     error(train)=2.41e+00, acc(train)=9.98e-02, error(valid)=2.42e+00, acc(valid)=9.61e-02
# Epoch 27: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 28: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 29: 1.7s to complete
#     error(train)=2.36e+00, acc(train)=1.04e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 30: 1.6s to complete
#     error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01
# Epoch 31: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.35e+00, acc(valid)=1.03e-01
# Epoch 32: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 33: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.32e+00, acc(valid)=9.67e-02
# Epoch 34: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 35: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.33e+00, acc(valid)=9.91e-02
# Epoch 36: 1.6s to complete
#     error(train)=2.38e+00, acc(train)=9.90e-02, error(valid)=2.38e+00, acc(valid)=9.67e-02
# Epoch 37: 1.4s to complete
#     error(train)=2.41e+00, acc(train)=9.94e-02, error(valid)=2.41e+00, acc(valid)=9.90e-02
# Epoch 38: 1.4s to complete
#     error(train)=2.34e+00, acc(train)=9.72e-02, error(valid)=2.34e+00, acc(valid)=9.83e-02
# Epoch 39: 1.5s to complete
#     error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 40: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# Epoch 41: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=9.01e-02, error(valid)=2.34e+00, acc(valid)=9.15e-02
# Epoch 42: 1.7s to complete
#     error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 43: 1.7s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 44: 1.6s to complete
#     error(train)=2.36e+00, acc(train)=9.68e-02, error(valid)=2.36e+00, acc(valid)=1.01e-01
# Epoch 45: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=9.98e-02, error(valid)=2.32e+00, acc(valid)=9.61e-02
# Epoch 46: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 47: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.04e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 48: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 49: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 50: 1.6s to complete
#     error(train)=2.39e+00, acc(train)=9.01e-02, error(valid)=2.38e+00, acc(valid)=9.15e-02
# Epoch 51: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 52: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.33e+00, acc(valid)=9.91e-02
# Epoch 53: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 54: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=9.86e-02, error(valid)=2.38e+00, acc(valid)=9.91e-02
# Epoch 55: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 56: 1.6s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 57: 1.7s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 58: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 59: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 60: 1.7s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 61: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 62: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 63: 1.8s to complete
#     error(train)=2.33e+00, acc(train)=1.04e-01, error(valid)=2.33e+00, acc(valid)=1.09e-01
# Epoch 64: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=9.01e-02, error(valid)=2.35e+00, acc(valid)=9.15e-02
# Epoch 65: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.68e-02, error(valid)=2.35e+00, acc(valid)=1.01e-01
# Epoch 66: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 67: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 68: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 69: 1.6s to complete
#     error(train)=2.36e+00, acc(train)=1.03e-01, error(valid)=2.36e+00, acc(valid)=1.09e-01
# Epoch 70: 1.6s to complete
#     error(train)=2.38e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 71: 1.7s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01
# Epoch 72: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=1.03e-01, error(valid)=2.37e+00, acc(valid)=1.09e-01
# Epoch 73: 1.7s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 74: 1.7s to complete
#     error(train)=2.38e+00, acc(train)=1.04e-01, error(valid)=2.38e+00, acc(valid)=1.09e-01
# Epoch 75: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 76: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 77: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 78: 1.6s to complete
#     error(train)=2.37e+00, acc(train)=9.90e-02, error(valid)=2.37e+00, acc(valid)=9.67e-02
# Epoch 79: 1.5s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 80: 1.5s to complete
#     error(train)=2.35e+00, acc(train)=9.86e-02, error(valid)=2.35e+00, acc(valid)=9.91e-02
# Epoch 81: 1.6s to complete
#     error(train)=2.32e+00, acc(train)=9.98e-02, error(valid)=2.32e+00, acc(valid)=9.61e-02
# Epoch 82: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 83: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 84: 1.5s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 85: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 86: 1.6s to complete
#     error(train)=2.40e+00, acc(train)=9.01e-02, error(valid)=2.40e+00, acc(valid)=9.15e-02
# Epoch 87: 1.5s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 88: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 89: 1.6s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 90: 1.5s to complete
#     error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 91: 1.5s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 92: 1.5s to complete
#     error(train)=2.37e+00, acc(train)=9.68e-02, error(valid)=2.36e+00, acc(valid)=1.01e-01
# Epoch 93: 1.6s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 94: 1.5s to complete
#     error(train)=2.37e+00, acc(train)=9.90e-02, error(valid)=2.38e+00, acc(valid)=9.67e-02
# Epoch 95: 1.6s to complete
#     error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 96: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 97: 1.7s to complete
#     error(train)=2.34e+00, acc(train)=1.04e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 98: 1.7s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 99: 1.5s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 100: 1.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.35e+00, acc(valid)=9.67e-02
# E:\Programm\Python\workplace\jupyter\mlp\mlpractical\mlp\errors.py:171: RuntimeWarning: overflow encountered in exp
#   probs = np.exp(outputs)
# E:\Programm\Python\workplace\jupyter\mlp\mlpractical\mlp\errors.py:172: RuntimeWarning: invalid value encountered in true_divide
#   probs /= probs.sum(-1)[:, None]
# Epoch 1: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 2: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 3: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 4: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 5: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 6: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 7: 1.8s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 8: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 9: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 10: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 11: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 12: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 13: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 14: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 15: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 16: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 17: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 18: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 19: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 20: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 21: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 22: 1.8s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 23: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 24: 2.0s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 25: 1.8s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 26: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 27: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 28: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 29: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 30: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 31: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 32: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 33: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 34: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 35: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 36: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 37: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 38: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 39: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 40: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 41: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 42: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 43: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 44: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 45: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 46: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 47: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 48: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 49: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 50: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 51: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 52: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 53: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 54: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 55: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 56: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 57: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 58: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 59: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 60: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 61: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 62: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 63: 1.7s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 64: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 65: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 66: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 67: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 68: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 69: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 70: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 71: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 72: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 73: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 74: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 75: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 76: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 77: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 78: 1.5s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 79: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 80: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 81: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 82: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 83: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 84: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 85: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 86: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 87: 1.6s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 88: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 89: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 90: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 91: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 92: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 93: 1.4s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 94: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 95: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 96: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 97: 1.1s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 98: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 99: 1.3s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02
# Epoch 100: 1.2s to complete
#     error(train)=nan, acc(train)=9.86e-02, error(valid)=nan, acc(valid)=9.91e-02

# %% [markdown]
# Plot the training set error against epoch number for all different regularisation schemes on the same axis. On a second axis plot the validation set error against epoch number for all the different regularisation schemes. Interpret and comment on what you see.

# %%
x= range(1,101)
fig = plt.figure(figsize=(8, 4))
ax_1 = fig.add_subplot(111)
ax_1.set_xlabel("Epoch")
ax_2 = ax_1.twinx()
ax_1.set_ylabel("Val. Acc.")
ax_2.set_ylabel("Train. Acc.")

fig2 = plt.figure(figsize=(8, 4))
ax_3 = fig2.add_subplot(111)
ax_3.set_xlabel("Epoch")
ax_4 = ax_3.twinx()
ax_3.set_ylabel("Val. Acc.")
ax_4.set_ylabel("Train. Acc.")

lns1 = ax_1.plot(x, error_val_l1[0], '-', label="L1 1e-5 Val.")
lns2 = ax_1.plot(x, error_val_l1[1], '-', label="L1 1e-3 Val.")
lns3 = ax_3.plot(x, error_val_l2[0], '-', label="L2 1e-4 Val.")
lns4 = ax_3.plot(x, error_val_l2[1], '-', label="L2 1e-2 Val.")
lns5 = ax_2.plot(x, error_train_l1[0], '--', label="L1 1e-5 Train.")
lns6 = ax_2.plot(x, error_train_l1[1], '--', label="L1 1e-3 Train.")
lns7 = ax_4.plot(x, error_train_l2[0], '--', label="L2 1e-4 Train.")
lns8 = ax_4.plot(x, error_train_l2[1], '--', label="L2 1e-2 Train.")

lns = lns1 + lns2 +lns5+lns6
labels = [l.get_label() for l in lns]
ax_1.legend(lns, labels, loc=0)

lns = lns3 + lns4 +lns7+lns8
labels = [l.get_label() for l in lns]
ax_3.legend(lns, labels, loc=0)

# %%
# Out:
# [array([2.32148499, 2.33672788, 2.33368585, 2.33795287, 2.34356639,
#         2.31883204, 2.32555431, 2.33010427, 2.33227157, 2.36787539,
#         2.398534  , 2.33602996, 2.37598945, 2.38686651, 2.31718077,
#         2.36029336, 2.36192872, 2.32107029, 2.34102242, 2.34914977,
#         2.32870121, 2.34260427, 2.32046565, 2.33904756, 2.38655988,
#         2.42473849, 2.33527683, 2.35098432, 2.35481638, 2.31175072,
#         2.35101369, 2.3366355 , 2.31522369, 2.35366426, 2.33337175,
#         2.37990387, 2.40624759, 2.34119506, 2.3310768 , 2.35182465,
#         2.34442044, 2.33474866, 2.36982116, 2.35772614, 2.32331962,
#         2.32763213, 2.34052306, 2.33219791, 2.34234955, 2.38498012,
#         2.34374231, 2.33201146, 2.33806668, 2.37904673, 2.3472023 ,
#         2.36986301, 2.33991262, 2.36768762, 2.32553664, 2.33128689,
#         2.33621832, 2.34426914, 2.3251028 , 2.34563702, 2.34587966,
#         2.34090243, 2.31853275, 2.32914928, 2.36390566, 2.3677151 ,
#         2.36723498, 2.37060096, 2.35955829, 2.3758962 , 2.33790456,
#         2.33393974, 2.35755701, 2.36748454, 2.37103606, 2.34683638,
#         2.32263734, 2.32219779, 2.31884961, 2.3445245 , 2.34242603,
#         2.39827816, 2.33022655, 2.34003963, 2.35222325, 2.35987836,
#         2.34673407, 2.36314372, 2.32523875, 2.37654622, 2.31714787,
#         2.33698789, 2.33705402, 2.3593899 , 2.32362996, 2.34891356]),
#  array([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan])]

# %% [markdown]
# The cell below defines two functions for visualising the first layer weights of the models trained above. The first plots a histogram of the weight values and the second plots the first layer weights as feature maps, i.e. each row of the first layer weight matrix (corresponding to the weights going from the input MNIST image to a particular first layer output) is visualised as a $28\times 28$ image. In these feature maps white corresponds to negative weights, black to positive weights and grey to weights close to zero.
#
# Use these functions to plot a histogram and feature map visualisation for the first layer weights of each model trained above. You should try to interpret the plots in the context of what you were told in the lecture about the behaviour of L1 versus L2 regularisation.

# %%
def plot_param_histogram(param, fig_size=(6, 3), interval=[-1.5, 1.5]):
    """Plots a normalised histogram of an array of parameter values."""
    fig = plt.figure(figsize=fig_size)
    ax = fig.add_subplot(111)
    ax.hist(param.flatten(), 50, interval, density=True)
    ax.set_xlabel('Parameter value')
    ax.set_ylabel('Normalised frequency density')
    return fig, ax

def visualise_first_layer_weights(model,weights, fig_size=(5, 5)):
    """Plots a grid of first layer weights as feature maps."""
    fig = plt.figure(figsize=fig_size)
    num_feature_maps = weights.shape[0]
    grid_size = int(num_feature_maps**0.5)
    max_abs = np.abs(model.params[0]).max()
    tiled = -np.ones((30 * grid_size, 
                      30 * num_feature_maps // grid_size)) * max_abs
    for i, fm in enumerate(model.params[0]):
        r, c = i % grid_size, i // grid_size
        tiled[1 + r * 30:(r + 1) * 30 - 1, 
              1 + c * 30:(c + 1) * 30 - 1] = fm.reshape((28, 28))
    ax = fig.add_subplot(111)
    max_abs = np.abs(tiled).max()
    ax.imshow(tiled, cmap='Greys', vmin=-max_abs, vmax=max_abs)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

# %%
plot_param_histogram(L1_models[0].params[0])
visualise_first_layer_weights(L1_models[0],L1_models[0].params[0])
# Out:
# (<Figure size 360x360 with 1 Axes>, <AxesSubplot:>)

# %% [markdown]
# ## Exercise 3: Random data augmentation
#
# Another technique mentioned in the lectures for trying to reduce overfitting is to artificially augment the training data set by performing random transformations to the original training data inputs. The idea is to produce further artificial inputs corresponding to the same target class as the original input. The closer the artificially generated inputs are appearing like the true inputs the better, as they provide more realistic additional examples for the model to learn from.
#
# For the handwritten image inputs in the MNIST dataset, an obvious way to considering augmenting the dataset is to apply small rotations to the original images. Providing the rotations are small we would generally expect that what we would identify as the class of a digit image will remain the same.
#
# Implement a function which given a batch of MNIST images as 784-dimensional vectors, i.e. an array of shape `(batch_size, 784)`
#
#   * chooses 25% of the images in the batch at random
#   * for each image in the 25% chosen, rotates the image by a random angle in $\left[-30^\circ,\,30^\circ\right]$
#   * returns a new array of size `(batch_size, 784)` in which the rows corresponding to the 25% chosen images are the vectors corresponding to the new randomly rotated images, while the remaining rows correspond to the original images.
#
# You will need to make use of the [`scipy.ndimage.interpolation.rotate`](https://docs.scipy.org/doc/scipy-0.16.0/reference/generated/scipy.ndimage.interpolation.rotate.html#scipy.ndimage.interpolation.rotate) function which is imported below for you. For computational efficiency you should use bilinear interpolation by setting `order=1` as a keyword argument to this function rather than using the default of bicubic interpolation. Additionally you should make sure the original shape of the images is maintained by passing a `reshape=False` keyword argument.

# %%
from scipy.ndimage.interpolation import rotate

def random_rotation(inputs, rng):
    """Randomly rotates a subset of images in a batch.
    
    Args:
        inputs: Input image batch, an array of shape (batch_size, 784).
        rng: A seeded random number generator.
        
    Returns:
        An array of shape (batch_size, 784) corresponding to a copy
        of the original `inputs` array with the randomly selected
        images rotated by a random angle. The original `inputs`
        array should not be modified.
    """
    batch_size= inputs.shape[0]
    num = batch_size//4
    index= np.random.choice(np.arange(batch_size), size=num, replace=False)
    for i in index:
        angle =np.random.choice([-30,30])
        inputs[i,:]=rotate(inputs[i,:].reshape(28,28),order=1,reshape=False,angle=angle).reshape(-1)
    return inputs

# %% [markdown]
# Use the cell below to test your implementation. This uses the `show_batch_of_images` function we implemented in the first lab notebook to visualise the images in a batch before and after application of the random rotation transformation.

# %%
from mlp.data_providers import MNISTDataProvider
import matplotlib.pyplot as plt
def show_batch_of_images(img_batch, fig_size=(3, 3)):
    fig = plt.figure(figsize=fig_size)
    batch_size, im_height, im_width = img_batch.shape
    # calculate no. columns per grid row to give square grid
    grid_size = int(batch_size**0.5)
    # intialise empty array to tile image grid into
    tiled = np.empty((im_height * grid_size, 
                      im_width * batch_size // grid_size))
    # iterate over images in batch + indexes within batch
    for i, img in enumerate(img_batch):
        # calculate grid row and column indices
        r, c = i % grid_size, i // grid_size
        tiled[r * im_height:(r + 1) * im_height, 
              c * im_height:(c + 1) * im_height] = img
    ax = fig.add_subplot(111)
    ax.imshow(tiled, cmap='Greys') #, vmin=0., vmax=1.)
    ax.axis('off')
    fig.tight_layout()
    plt.show()
    return fig, ax

test_data = MNISTDataProvider('test', 100, rng=rng)
inputs, targets = test_data.next()
_ = show_batch_of_images(inputs.reshape((-1, 28, 28)))
transformed_inputs = random_rotation(inputs, rng)
_ = show_batch_of_images(transformed_inputs.reshape((-1, 28, 28)))

# %% [markdown]
# ## Exercise 4: Training with data augmentation
#
# One simple way to use data augmentation is to just statically augment the training data set - for example we could iterate through the training dataset applying a transformation function like that implemented above to generate new artificial inputs, and use both the original and newly generated data in a new data provider object. We are quite limited however in how far we can augment the dataset by with a static method like this however - if we wanted to apply 9 random rotations to each image in the original datase, we would end up with a dataset with 10 times the memory requirements and that would take 10 times as long to run through each epoch.
#
# An alternative is to randomly augment the data on the fly as we iterate through the data provider in each epoch. In this method a new data provider class can be defined that inherits from the original data provider to be augmented, and provides a new `next` method which applies a random transformation function like that implemented in the previous exercise to each input batch before returning it. This method means that on every epoch a different set of training examples are provided to the model and so in some ways corresponds to an 'infinite' data set (although the amount of variability in the dataset will still be significantly less than the variability in all possible digit images). Compared to static augmentation, this dynamic augmentation scheme comes at the computational cost of having to apply the random transformation each time a new batch is provided. We can vary this overhead by changing the proportion of images in a batch randomly transformed.
#
# An implementation of this scheme has been provided for the MNIST data set in the `AugmentedMNISTDataProvider` object in the `mlp.data_providers` module. In addition to the arguments of the original `MNISTDataProvider.__init__` method, this additional takes a `transformer` argument, which should be a function which takes as arguments an inputs batch array and a random number generator object, and returns an array corresponding to a random transformation of the inputs.
#
# Train a model with the same architecture as in exercise 3 and with no L1 / L2 regularisation using a training data provider which randomly augments the training images using your `random_rotation` transformer function. Plot the training and validation set errors over the training epochs and compare this plot to your previous results from exercise 3.

# %%
from mlp.data_providers import AugmentedMNISTDataProvider

aug_train_data = AugmentedMNISTDataProvider('train', rng=rng, transformer=random_rotation)
valid_data = MNISTDataProvider('valid', batch_size=batch_size, rng=rng)
test_data = MNISTDataProvider('test', batch_size=batch_size, rng=rng)

train_data.reset()
valid_data.reset()
test_data.reset()
lr = 0.9
num_epochs=100
weights_init = GlorotUniformInit(0.5, rng)
biases_init = ConstantInit(0.)
input_dim, output_dim, hidden_dim = 784, 10, 100


model = MultipleLayerModel([
    AffineLayer(input_dim, hidden_dim, weights_init,
                biases_init, weights_penalty=None),
    ReluLayer(),
    AffineLayer(hidden_dim, hidden_dim, weights_init,
                biases_init, weights_penalty=None),
    ReluLayer(),
    AffineLayer(hidden_dim, output_dim, weights_init,
                biases_init, weights_penalty=None)
])


learning_rule = MomentumLearningRule(learning_rate=lr)
error = CrossEntropySoftmaxError()
data_monitors = {'acc': lambda y, t: (y.argmax(-1) == t.argmax(-1)).mean()}


# Use the created objects to initialise a new Optimiser instance.


stats2  = []

optimiser = Optimiser(model, error, learning_rule, train_data, valid_data, data_monitors)
stat, keys, run_time = optimiser.train(num_epochs=num_epochs, stats_interval=1)
error_val=stat[1:, keys['error(valid)']]
error_train=stat[1:, keys['error(train)']]

stats2.append(stat)

x= range(1,101)
fig = plt.figure(figsize=(8, 4))
ax_1 = fig.add_subplot(111)
ax_1.set_xlabel("Epoch")
ax_2 = ax_1.twinx()
ax_1.set_ylabel("Val. Acc.")
ax_2.set_ylabel("Train. Acc.")

lns1 = ax_1.plot(x, error_val, '-', label="Val. Err.")

lns2 = ax_2.plot(x, error_train, '--', label="Train. Err,")
lns = lns1 + lns2
labels = [l.get_label() for l in lns]
ax_1.legend(lns, labels, loc=0)
# Out:
# Epoch 1: 1.0s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 2: 1.0s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 3: 1.0s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 4: 1.0s to complete
#     error(train)=2.36e+00, acc(train)=9.94e-02, error(valid)=2.37e+00, acc(valid)=9.90e-02
# Epoch 5: 1.0s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 6: 0.9s to complete
#     error(train)=2.36e+00, acc(train)=9.72e-02, error(valid)=2.36e+00, acc(valid)=9.83e-02
# Epoch 7: 1.4s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 8: 2.4s to complete
#     error(train)=2.35e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 9: 2.5s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 10: 2.4s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 11: 2.5s to complete
#     error(train)=2.37e+00, acc(train)=1.14e-01, error(valid)=2.37e+00, acc(valid)=1.06e-01
# Epoch 12: 2.5s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 13: 2.4s to complete
#     error(train)=2.31e+00, acc(train)=9.68e-02, error(valid)=2.31e+00, acc(valid)=1.01e-01
# Epoch 14: 2.5s to complete
#     error(train)=2.35e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 15: 2.5s to complete
#     error(train)=2.32e+00, acc(train)=1.02e-01, error(valid)=2.32e+00, acc(valid)=1.03e-01
# Epoch 16: 2.5s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 17: 2.5s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 18: 2.4s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.03e-01
# Epoch 19: 2.5s to complete
#     error(train)=2.35e+00, acc(train)=9.01e-02, error(valid)=2.34e+00, acc(valid)=9.15e-02
# Epoch 20: 3.2s to complete
#     error(train)=2.37e+00, acc(train)=9.01e-02, error(valid)=2.37e+00, acc(valid)=9.15e-02
# Epoch 21: 2.4s to complete
#     error(train)=2.34e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.03e-01
# Epoch 22: 2.7s to complete
#     error(train)=2.36e+00, acc(train)=1.14e-01, error(valid)=2.36e+00, acc(valid)=1.06e-01
# Epoch 23: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 24: 2.5s to complete
#     error(train)=2.36e+00, acc(train)=1.03e-01, error(valid)=2.36e+00, acc(valid)=1.09e-01
# Epoch 25: 2.5s to complete
#     error(train)=2.35e+00, acc(train)=1.02e-01, error(valid)=2.35e+00, acc(valid)=1.03e-01
# Epoch 26: 3.0s to complete
#     error(train)=2.35e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 27: 2.5s to complete
#     error(train)=2.33e+00, acc(train)=9.86e-02, error(valid)=2.33e+00, acc(valid)=9.91e-02
# Epoch 28: 2.4s to complete
#     error(train)=2.38e+00, acc(train)=9.90e-02, error(valid)=2.39e+00, acc(valid)=9.67e-02
# Epoch 29: 2.4s to complete
#     error(train)=2.34e+00, acc(train)=1.02e-01, error(valid)=2.34e+00, acc(valid)=1.03e-01
# Epoch 30: 2.5s to complete
#     error(train)=2.43e+00, acc(train)=9.90e-02, error(valid)=2.44e+00, acc(valid)=9.67e-02
# Epoch 31: 2.8s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 32: 2.4s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 33: 2.4s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 34: 2.5s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 35: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 36: 2.5s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 37: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 38: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 39: 2.6s to complete
#     error(train)=2.32e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 40: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 41: 2.6s to complete
#     error(train)=2.32e+00, acc(train)=1.14e-01, error(valid)=2.32e+00, acc(valid)=1.06e-01
# Epoch 42: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=9.68e-02, error(valid)=2.33e+00, acc(valid)=1.01e-01
# Epoch 43: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 44: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 45: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 46: 2.6s to complete
#     error(train)=2.32e+00, acc(train)=9.01e-02, error(valid)=2.32e+00, acc(valid)=9.15e-02
# Epoch 47: 2.6s to complete
#     error(train)=2.39e+00, acc(train)=1.02e-01, error(valid)=2.39e+00, acc(valid)=1.03e-01
# Epoch 48: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 49: 2.6s to complete
#     error(train)=2.32e+00, acc(train)=9.94e-02, error(valid)=2.32e+00, acc(valid)=9.90e-02
# Epoch 50: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 51: 2.7s to complete
#     error(train)=2.40e+00, acc(train)=1.03e-01, error(valid)=2.40e+00, acc(valid)=1.09e-01
# Epoch 52: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 53: 2.6s to complete
#     error(train)=2.32e+00, acc(train)=9.86e-02, error(valid)=2.32e+00, acc(valid)=9.91e-02
# Epoch 54: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 55: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=9.90e-02, error(valid)=2.32e+00, acc(valid)=9.67e-02
# Epoch 56: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
# Epoch 57: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.72e-02, error(valid)=2.34e+00, acc(valid)=9.83e-02
# Epoch 58: 2.6s to complete
#     error(train)=2.36e+00, acc(train)=9.90e-02, error(valid)=2.36e+00, acc(valid)=9.67e-02
# Epoch 59: 2.6s to complete
#     error(train)=2.41e+00, acc(train)=1.02e-01, error(valid)=2.41e+00, acc(valid)=1.03e-01
# Epoch 60: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 61: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 62: 2.6s to complete
#     error(train)=2.36e+00, acc(train)=1.03e-01, error(valid)=2.35e+00, acc(valid)=1.09e-01
# Epoch 63: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 64: 2.6s to complete
#     error(train)=2.34e+00, acc(train)=9.90e-02, error(valid)=2.34e+00, acc(valid)=9.67e-02
# Epoch 65: 2.7s to complete
#     error(train)=2.36e+00, acc(train)=9.86e-02, error(valid)=2.36e+00, acc(valid)=9.91e-02
# Epoch 66: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=1.03e-01, error(valid)=2.32e+00, acc(valid)=1.09e-01
# Epoch 67: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 68: 2.7s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.37e+00, acc(valid)=9.61e-02
# Epoch 69: 2.7s to complete
#     error(train)=2.37e+00, acc(train)=9.86e-02, error(valid)=2.37e+00, acc(valid)=9.91e-02
# Epoch 70: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 71: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=9.98e-02, error(valid)=2.34e+00, acc(valid)=9.61e-02
# Epoch 72: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 73: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=9.68e-02, error(valid)=2.34e+00, acc(valid)=1.01e-01
# Epoch 74: 2.7s to complete
#     error(train)=2.35e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 75: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 76: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=9.90e-02, error(valid)=2.33e+00, acc(valid)=9.67e-02
# Epoch 77: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=9.68e-02, error(valid)=2.32e+00, acc(valid)=1.01e-01
# Epoch 78: 2.7s to complete
#     error(train)=2.31e+00, acc(train)=1.14e-01, error(valid)=2.31e+00, acc(valid)=1.06e-01
# Epoch 79: 2.7s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 80: 2.7s to complete
#     error(train)=2.36e+00, acc(train)=1.02e-01, error(valid)=2.36e+00, acc(valid)=1.03e-01
# Epoch 81: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=9.01e-02, error(valid)=2.33e+00, acc(valid)=9.15e-02
# Epoch 82: 2.8s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 83: 2.7s to complete
#     error(train)=2.32e+00, acc(train)=9.86e-02, error(valid)=2.32e+00, acc(valid)=9.91e-02
# Epoch 84: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=9.72e-02, error(valid)=2.33e+00, acc(valid)=9.83e-02
# Epoch 85: 2.7s to complete
#     error(train)=2.36e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 86: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 87: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=1.14e-01, error(valid)=2.34e+00, acc(valid)=1.06e-01
# Epoch 88: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=9.86e-02, error(valid)=2.34e+00, acc(valid)=9.91e-02
# Epoch 89: 2.7s to complete
#     error(train)=2.37e+00, acc(train)=9.98e-02, error(valid)=2.36e+00, acc(valid)=9.61e-02
# Epoch 90: 2.7s to complete
#     error(train)=2.38e+00, acc(train)=1.14e-01, error(valid)=2.38e+00, acc(valid)=1.06e-01
# Epoch 91: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=1.14e-01, error(valid)=2.33e+00, acc(valid)=1.06e-01
# Epoch 92: 2.7s to complete
#     error(train)=2.34e+00, acc(train)=1.03e-01, error(valid)=2.34e+00, acc(valid)=1.09e-01
# Epoch 93: 2.7s to complete
#     error(train)=2.35e+00, acc(train)=1.14e-01, error(valid)=2.35e+00, acc(valid)=1.06e-01
# Epoch 94: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=1.02e-01, error(valid)=2.33e+00, acc(valid)=1.03e-01
# Epoch 95: 2.6s to complete
#     error(train)=2.39e+00, acc(train)=9.98e-02, error(valid)=2.38e+00, acc(valid)=9.61e-02
# Epoch 96: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.33e+00, acc(valid)=9.90e-02
# Epoch 97: 2.7s to complete
#     error(train)=2.33e+00, acc(train)=9.98e-02, error(valid)=2.33e+00, acc(valid)=9.61e-02
# Epoch 98: 2.6s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 99: 2.6s to complete
#     error(train)=2.35e+00, acc(train)=9.94e-02, error(valid)=2.35e+00, acc(valid)=9.90e-02
# Epoch 100: 2.6s to complete
#     error(train)=2.33e+00, acc(train)=9.94e-02, error(valid)=2.34e+00, acc(valid)=9.90e-02
